# %% [markdown]
# # Table of Contents
#
# 1. Importing Libraries
# 2. Importing Dataframes
# 3. Data Cleaning & Wrangling for 2015
# 4. Data Cleaning & Wrangling for 2016
# 5. Data Cleaning & Wrangling for 2017
# 6. Data Cleaning & Wrangling for 2018
# 7. Data Cleaning & Wrangling for 2019
# 8. Data Cleaning & Wrangling for 2020
# 9. Data Cleaning & Wrangling for 2021
# 10. Data Cleaning & Wrangling for 2022
# 11. Merging Dataflames
# 12. Descriptive Statistics
# 13. Exporting Cleaned Dataframe

# %% [markdown]
# ### 1. Importing Libraries

# %%
import pandas as pd
import numpy as np 
import os

# %% [markdown]
# ### 2. Importing Dataframe

# %%
# Defining path
path = r'/Users/sina/Desktop/Projects/A6'

# %%
# importing customers DF
year15 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2015.csv'), index_col = False)

# %%
year16 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2016.csv'), index_col = False)

# %%
year17 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2017.csv'), index_col = False)

# %%
year18 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2018.csv'), index_col = False)

# %%
year19 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2019.csv'), index_col = False)

# %%
year20 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2020.csv'), index_col = False)

# %%
year21 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2021.csv'), index_col = False)

# %%
year22 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2022.csv'), index_col = False)

# %% [markdown]
# ### 3. Data Cleaning & Wrangling for 2015

# %%
# check the shape of the Dataframe
year15.shape
# Out:
# (158, 12)

# %%
# check the info of dataframe
year15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
# describe the data
year15.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
#remove unnecessary columns
year15.drop(['Standard Error'], axis=1, inplace=True)

# %%
year15.head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# ...

# %%
# add new column
year15 ['Year'] = 2015

# %%
year15.head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  Year
# 0                        0.41978     0.29678            2.51738  2015
# ...

# %%
# rename columns
year15.rename(columns = {'Happiness Rank':'Rank', 'Family':'Family (Social Support)', 'Freedom':'Freedom (Life Choices)', 'Generosity': 'Generosity (Donations to Charity)'}, inplace = True)

# %%
year15.head(5)
# Out:
#        Country          Region  Rank  Happiness Score  \
# 0  Switzerland  Western Europe     1            7.587
# 1      Iceland  Western Europe     2            7.561
# 2      Denmark  Western Europe     3            7.527
# 3       Norway  Western Europe     4            7.522
# 4       Canada   North America     5            7.427
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                   1.39651                  1.34951
# 1                   1.30232                  1.40223
# 2                   1.32548                  1.36058
# 3                   1.45900                  1.33095
# 4                   1.32629                  1.32261
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                   0.94143                 0.66557
# 1                   0.94784                 0.62877
# 2                   0.87464                 0.64938
# 3                   0.88521                 0.66973
# ...

# %%
#change the order of columns

year15 = year15[['Rank', 'Year', 'Country', 'Region', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Generosity (Donations to Charity)', 'Dystopia Residual']]

# %%
year15.head(5)
# Out:
#    Rank  Year      Country          Region  Happiness Score  \
# 0     1  2015  Switzerland  Western Europe            7.587
# 1     2  2015      Iceland  Western Europe            7.561
# 2     3  2015      Denmark  Western Europe            7.527
# 3     4  2015       Norway  Western Europe            7.522
# 4     5  2015       Canada   North America            7.427
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                   1.39651                  1.34951
# 1                   1.30232                  1.40223
# 2                   1.32548                  1.36058
# 3                   1.45900                  1.33095
# 4                   1.32629                  1.32261
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                   0.94143                 0.66557
# 1                   0.94784                 0.62877
# 2                   0.87464                 0.64938
# 3                   0.88521                 0.66973
# ...

# %%
year15.drop(['Dystopia Residual'], axis=1, inplace=True)

# %%
# checking the null data
year15.isnull().sum()
# Out:
# Rank                                 0
# Year                                 0
# Country                              0
# Region                               0
# Happiness Score                      0
# Economy (GDP per Capita)             0
# Family (Social Support)              0
# Health (Life Expectancy)             0
# Freedom (Life Choices)               0
# Trust (Government Corruption)        0
# Generosity (Donations to Charity)    0
# dtype: int64

# %%
# check for duplicates

year15[year15.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Generosity (Donations to Charity)]
# Index: []

# %%
# drop the other missing values
year15_clean = year15.dropna()

# %%
year15_clean.shape
# Out:
# (158, 11)

# %%
year15_clean.describe()
# Out:
#              Rank    Year  Happiness Score  Economy (GDP per Capita)  \
# count  158.000000   158.0       158.000000                158.000000
# mean    79.493671  2015.0         5.375734                  0.846137
# std     45.754363     0.0         1.145010                  0.403121
# min      1.000000  2015.0         2.839000                  0.000000
# 25%     40.250000  2015.0         4.526000                  0.545808
# 50%     79.500000  2015.0         5.232500                  0.910245
# 75%    118.750000  2015.0         6.243750                  1.158448
# max    158.000000  2015.0         7.587000                  1.690420
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               158.000000                158.000000
# mean                  0.991046                  0.630259
# std                   0.272369                  0.247078
# min                   0.000000                  0.000000
# ...

# %%
year15_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Rank                               158 non-null    int64
#  1   Year                               158 non-null    int64
#  2   Country                            158 non-null    object
#  3   Region                             158 non-null    object
#  4   Happiness Score                    158 non-null    float64
#  5   Economy (GDP per Capita)           158 non-null    float64
#  6   Family (Social Support)            158 non-null    float64
#  7   Health (Life Expectancy)           158 non-null    float64
#  8   Freedom (Life Choices)             158 non-null    float64
#  9   Trust (Government Corruption)      158 non-null    float64
#  10  Generosity (Donations to Charity)  158 non-null    float64
# ...

# %%
#Export df_ords
year15_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'year15_clean.csv'))

# %% [markdown]
# ### 4. Data Cleaning & Wrangling for 2016

# %%
# check the shape of the Dataframe
year16.shape
# Out:
# (157, 13)

# %%
# check the info of dataframe
year16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
#remove unnecessary columns
year16.drop(['Lower Confidence Interval', 'Upper Confidence Interval'], axis=1, inplace=True)

# %%
year16.head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
# 3                   1.57744  1.12690                   0.79579  0.59609
# 4                   1.40598  1.13464                   0.81091  0.57104
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# ...

# %%
# rename columns
year16.rename(columns = {'Happiness Rank':'Rank', 'Family':'Family (Social Support)', 'Freedom':'Freedom (Life Choices)', 'Generosity': 'Generosity (Donations to Charity)'}, inplace = True)

# %%
# add new column
year16 ['Year'] = 2016

# %%
#change the order of columns

year16 = year16[['Rank', 'Year', 'Country', 'Region', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Generosity (Donations to Charity)', 'Dystopia Residual']]

# %%
# dropping unnecessary column for merge
year16.drop(['Dystopia Residual'], axis=1, inplace=True)

# %%
year16.head(5)
# Out:
#    Rank  Year      Country          Region  Happiness Score  \
# 0     1  2016      Denmark  Western Europe            7.526
# 1     2  2016  Switzerland  Western Europe            7.509
# 2     3  2016      Iceland  Western Europe            7.501
# 3     4  2016       Norway  Western Europe            7.498
# 4     5  2016      Finland  Western Europe            7.413
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                   1.44178                  1.16374
# 1                   1.52733                  1.14524
# 2                   1.42666                  1.18326
# 3                   1.57744                  1.12690
# 4                   1.40598                  1.13464
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                   0.79504                 0.57941
# 1                   0.86303                 0.58557
# 2                   0.86733                 0.56624
# 3                   0.79579                 0.59609
# ...

# %%
# checking the null data
year16.isnull().sum()
# Out:
# Rank                                 0
# Year                                 0
# Country                              0
# Region                               0
# Happiness Score                      0
# Economy (GDP per Capita)             0
# Family (Social Support)              0
# Health (Life Expectancy)             0
# Freedom (Life Choices)               0
# Trust (Government Corruption)        0
# Generosity (Donations to Charity)    0
# dtype: int64

# %%
# check for duplicates
year16[year16.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Generosity (Donations to Charity)]
# Index: []

# %%
# drop the other missing values
year16_clean = year16.dropna()

# %%
year16_clean.shape
# Out:
# (157, 11)

# %%
year16_clean.describe()
# Out:
#              Rank    Year  Happiness Score  Economy (GDP per Capita)  \
# count  157.000000   157.0       157.000000                157.000000
# mean    78.980892  2016.0         5.382185                  0.953880
# std     45.466030     0.0         1.141674                  0.412595
# min      1.000000  2016.0         2.905000                  0.000000
# 25%     40.000000  2016.0         4.404000                  0.670240
# 50%     79.000000  2016.0         5.314000                  1.027800
# 75%    118.000000  2016.0         6.269000                  1.279640
# max    157.000000  2016.0         7.526000                  1.824270
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               157.000000                157.000000
# mean                  0.793621                  0.557619
# std                   0.266706                  0.229349
# min                   0.000000                  0.000000
# ...

# %%
year16_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Rank                               157 non-null    int64
#  1   Year                               157 non-null    int64
#  2   Country                            157 non-null    object
#  3   Region                             157 non-null    object
#  4   Happiness Score                    157 non-null    float64
#  5   Economy (GDP per Capita)           157 non-null    float64
#  6   Family (Social Support)            157 non-null    float64
#  7   Health (Life Expectancy)           157 non-null    float64
#  8   Freedom (Life Choices)             157 non-null    float64
#  9   Trust (Government Corruption)      157 non-null    float64
#  10  Generosity (Donations to Charity)  157 non-null    float64
# ...

# %%
# Export df_ords
year16_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'year16_clean.csv'))

# %% [markdown]
# ### 5. Data Cleaning & Wrangling for 2017

# %%
# check the shape of the Dataframe
year17.shape
# Out:
# (155, 12)

# %%
# check the info of dataframe
year17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# ...

# %%
#remove unnecessary columns
year17.drop(['Whisker.high', 'Whisker.low'], axis=1, inplace=True)

# %%
# add new column
year17 ['Year'] = 2017

# %%
year17.head(5)
# Out:
#        Country  Happiness.Rank  Happiness.Score  Economy..GDP.per.Capita.  \
# 0       Norway               1            7.537                  1.616463
# 1      Denmark               2            7.522                  1.482383
# 2      Iceland               3            7.504                  1.480633
# 3  Switzerland               4            7.494                  1.564980
# 4      Finland               5            7.469                  1.443572
#
#      Family  Health..Life.Expectancy.   Freedom  Generosity  \
# 0  1.533524                  0.796667  0.635423    0.362012
# 1  1.551122                  0.792566  0.626007    0.355280
# 2  1.610574                  0.833552  0.627163    0.475540
# 3  1.516912                  0.858131  0.620071    0.290549
# 4  1.540247                  0.809158  0.617951    0.245483
#
#    Trust..Government.Corruption.  Dystopia.Residual  Year
# 0                       0.315964           2.277027  2017
# ...

# %%
# rename columns
year17.rename(columns = {'Happiness.Rank':'Rank', 'Happiness.Score':'Happiness Score', 'Economy..GDP.per.Capita.':'Economy (GDP per Capita)', 'Family':'Family (Social Support)', 'Health..Life.Expectancy.':'Health (Life Expectancy)','Freedom':'Freedom (Life Choices)', 'Generosity': 'Generosity (Donations to Charity)', 'Trust..Government.Corruption.':'Trust (Government Corruption)'}, inplace = True)

# %%
year17.head()
# Out:
#        Country  Rank  Happiness Score  Economy (GDP per Capita)  \
# 0       Norway     1            7.537                  1.616463
# 1      Denmark     2            7.522                  1.482383
# 2      Iceland     3            7.504                  1.480633
# 3  Switzerland     4            7.494                  1.564980
# 4      Finland     5            7.469                  1.443572
#
#    Family (Social Support)  Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                 1.533524                  0.796667                0.635423
# 1                 1.551122                  0.792566                0.626007
# 2                 1.610574                  0.833552                0.627163
# 3                 1.516912                  0.858131                0.620071
# 4                 1.540247                  0.809158                0.617951
#
#    Generosity (Donations to Charity)  Trust (Government Corruption)  \
# ...

# %%
# Correcting country name 
year17['Country'] = year17['Country'].replace('South Sudan', 'Sudan')

# %%
year17['Country'] = year17['Country'].replace('Taiwan Province of China', 'Taiwan')

# %%
year17['Country'] = year17['Country'].replace('Hong Kong S.A.R., China', 'Hong Kong')

# %%
# derive Region according to country names using loc()
year17.loc[year17['Country'].isin(['Australia', 'New Zealand']), 'Region'] = 'Australia and New Zealand'

# %%
year17.loc[year17['Country'].isin(['Albania', 'Armenia', 'Azerbaijan', 'Belarus', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czech Republic', 'Estonia', 'Georgia', 'Hungary', 'Kazakhstan', 'Kosovo', 'Kyrgyzstan', 'Latvia', 'Lithuania', 'Macedonia', 'Moldova', 'Montenegro', 'Poland','Romania', 'Russia', 'Serbia', 'Slovakia', 'Slovenia', 'Tajikistan', 'Turkmenistan', 'Ukraine', 'Uzbekistan']), 'Region'] = 'Central and Eastern Europe'

# %%
year17.loc[year17['Country'].isin(['China', 'Hong Kong', 'Japan', 'Mongolia', 'South Korea', 'Taiwan']), 'Region'] = 'Eastern Asia'

# %%
year17.loc[year17['Country'].isin(['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Costa Rica', 'Dominican Republic','Ecuador', 'El Salvador', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 'Peru', 'Suriname', 'Trinidad and Tobago', 'Uruguay', 'Uruguay']), 'Region'] = 'Latin America and Caribbean'

# %%
year17.loc[year17['Country'].isin(['Algeria', 'Bahrain','Egypt','Iran', 'Iraq', 'Israel', 'Jordan', 'Kuwait', 'Lebanon', 'Libya', 'Morocco', 'Oman', 'Palestinian Territories', 'Qatar', 'Saudi Arabia', 'Syria', 'Tunisia', 'Turkey', 'United Arab Emirates', 'Yemen']), 'Region'] = 'Middle East and Northern Africa'

# %%
year17.loc[year17['Country'].isin(['Canada', 'United States']), 'Region'] = 'North America'

# %%
year17.loc[year17['Country'].isin(['Cambodia', 'Indonesia', 'Laos', 'Malaysia', 'Myanmar', 'Philippines', 'Singapore', 'Thailand', 'Vietnam']), 'Region'] = 'Southeastern Asia'

# %%
year17.loc[year17['Country'].isin(['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Nepal', 'Pakistan', 'Sri Lanka']), 'Region'] = 'Southern Asia'

# %%
year17.loc[year17['Country'].isin(['Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Congo (Brazzaville)', 'Congo (Kinshasa)', 'Djibouti', 'Ethiopia', 'Gabon', 'Ghana', 'Guinea', 'Ivory Coast', 'Kenya', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Mozambique', 'Niger', 'Nigeria', 'Rwanda', 'Senegal', 'Sierra Leone', 'Somaliland region', 'South Africa', 'Sudan', 'Swaziland', 'Tanzania', 'Togo', 'Uganda', 'Zambia', 'Zimbabwe']), 'Region'] = 'Sub-Saharan Africa'

# %%
year17.loc[year17['Country'].isin(['Austria', 'Belgium', 'Cyprus', 'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Iceland', 'Ireland', 'Italy', 'Luxembourg', 'Malta', 'Netherlands', 'North Cyprus', 'Norway', 'Portugal', 'Spain', 'Sweden', 'Switzerland', 'United Kingdom']), 'Region'] = 'Western Europe'

# %%
year17.head(5)
# Out:
#        Country  Rank  Happiness Score  Economy (GDP per Capita)  \
# 0       Norway     1            7.537                  1.616463
# 1      Denmark     2            7.522                  1.482383
# 2      Iceland     3            7.504                  1.480633
# 3  Switzerland     4            7.494                  1.564980
# 4      Finland     5            7.469                  1.443572
#
#    Family (Social Support)  Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                 1.533524                  0.796667                0.635423
# 1                 1.551122                  0.792566                0.626007
# 2                 1.610574                  0.833552                0.627163
# 3                 1.516912                  0.858131                0.620071
# 4                 1.540247                  0.809158                0.617951
#
#    Generosity (Donations to Charity)  Trust (Government Corruption)  \
# ...

# %%
year17.rename(columns = {'Dystopia.Residual': 'Dystopia Residual'}, inplace = True)

# %%
year17 = year17[['Rank', 'Year', 'Country', 'Region', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Generosity (Donations to Charity)', 'Dystopia Residual']]

# %%
# dropping unnecessary column for merge
year17.drop(['Dystopia Residual'], axis=1, inplace=True)

# %%
year17.head(5)
# Out:
#    Rank  Year      Country          Region  Happiness Score  \
# 0     1  2017       Norway  Western Europe            7.537
# 1     2  2017      Denmark  Western Europe            7.522
# 2     3  2017      Iceland  Western Europe            7.504
# 3     4  2017  Switzerland  Western Europe            7.494
# 4     5  2017      Finland  Western Europe            7.469
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                  1.616463                 1.533524
# 1                  1.482383                 1.551122
# 2                  1.480633                 1.610574
# 3                  1.564980                 1.516912
# 4                  1.443572                 1.540247
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                  0.796667                0.635423
# 1                  0.792566                0.626007
# 2                  0.833552                0.627163
# 3                  0.858131                0.620071
# ...

# %%
# checking the null data
year17.isnull().sum()
# Out:
# Rank                                 0
# Year                                 0
# Country                              0
# Region                               4
# Happiness Score                      0
# Economy (GDP per Capita)             0
# Family (Social Support)              0
# Health (Life Expectancy)             0
# Freedom (Life Choices)               0
# Trust (Government Corruption)        0
# Generosity (Donations to Charity)    0
# dtype: int64

# %%
print("Missing Data:\n", year17[year17.isnull().any(axis=1)])
# Out:
# Missing Data:
#       Rank  Year    Country Region  Happiness Score  Economy (GDP per Capita)  \
# 49     50  2017     Belize    NaN            5.956                  0.907975
# 81     82  2017  Venezuela    NaN            5.250                  1.128431
# 92     93  2017    Somalia    NaN            5.151                  0.022643
# 110   111  2017    Namibia    NaN            4.574                  0.964434
#
#      Family (Social Support)  Health (Life Expectancy)  \
# 49                  1.081418                  0.450192
# 81                  1.431338                  0.617144
# 92                  0.721151                  0.113989
# 110                 1.098471                  0.338612
#
#      Freedom (Life Choices)  Trust (Government Corruption)  \
# 49                 0.547509                       0.096581
# 81                 0.153997                       0.064491
# 92                 0.602127                       0.282410
# ...

# %%
# Correcting missing data
year17.loc[year17['Country'].isin(['Belize', 'Venezuela']), 'Region'] = 'Latin America and Caribbean'

# %%
year17.loc[year17['Country'].isin(['Somalia', 'Namibia']), 'Region'] = 'Sub-Saharan Africa'

# %%
# checking the null data
year17.isnull().sum()
# Out:
# Rank                                 0
# Year                                 0
# Country                              0
# Region                               0
# Happiness Score                      0
# Economy (GDP per Capita)             0
# Family (Social Support)              0
# Health (Life Expectancy)             0
# Freedom (Life Choices)               0
# Trust (Government Corruption)        0
# Generosity (Donations to Charity)    0
# dtype: int64

# %%
# check for duplicates
year17[year17.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Generosity (Donations to Charity)]
# Index: []

# %%
# drop the other missing values
year17_clean = year17.dropna()

# %%
year17_clean.shape
# Out:
# (155, 11)

# %%
year17_clean.describe()
# Out:
#              Rank    Year  Happiness Score  Economy (GDP per Capita)  \
# count  155.000000   155.0       155.000000                155.000000
# mean    78.000000  2017.0         5.354019                  0.984718
# std     44.888751     0.0         1.131230                  0.420793
# min      1.000000  2017.0         2.693000                  0.000000
# 25%     39.500000  2017.0         4.505500                  0.663371
# 50%     78.000000  2017.0         5.279000                  1.064578
# 75%    116.500000  2017.0         6.101500                  1.318027
# max    155.000000  2017.0         7.537000                  1.870766
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               155.000000                155.000000
# mean                  1.188898                  0.551341
# std                   0.287263                  0.237073
# min                   0.000000                  0.000000
# ...

# %%
year17_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Rank                               155 non-null    int64
#  1   Year                               155 non-null    int64
#  2   Country                            155 non-null    object
#  3   Region                             155 non-null    object
#  4   Happiness Score                    155 non-null    float64
#  5   Economy (GDP per Capita)           155 non-null    float64
#  6   Family (Social Support)            155 non-null    float64
#  7   Health (Life Expectancy)           155 non-null    float64
#  8   Freedom (Life Choices)             155 non-null    float64
#  9   Trust (Government Corruption)      155 non-null    float64
#  10  Generosity (Donations to Charity)  155 non-null    float64
# ...

# %%
# Export df_ords
year17_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'year17_clean.csv'))

# %% [markdown]
# ### 6. Data Cleaning & Wrangling for 2018

# %%
# check the shape of the Dataframe
year18.shape
# Out:
# (156, 9)

# %%
# check the info of dataframe
year18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
# rename columns
year18.rename(columns = {'Overall rank':'Rank', 'Country or region':'Country', 'Score':'Happiness Score', 'GDP per capita':'Economy (GDP per Capita)', 'Social support':'Family (Social Support)', 'Healthy life expectancy': 'Health (Life Expectancy)', 'Freedom to make life choices': 'Freedom (Life Choices)', 'Generosity':'Generosity (Donations to Charity)', 'Perceptions of corruption':'Trust (Government Corruption)'}, inplace = True)

# %%
# add new column
year18 ['Year'] = 2018

# %%
# Correcting country name 
year18['Country'] = year18['Country'].replace('South Sudan', 'Sudan')
year18['Country'] = year18['Country'].replace('Trinidad & Tobago', 'Trinidad and Tobago')

# %%
# derive Region according to country names using loc()
year18.loc[year18['Country'].isin(['Australia', 'New Zealand']), 'Region'] = 'Australia and New Zealand'
year18.loc[year18['Country'].isin(['Albania', 'Armenia', 'Azerbaijan', 'Belarus', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czech Republic', 'Estonia', 'Georgia', 'Hungary', 'Kazakhstan', 'Kosovo', 'Kyrgyzstan', 'Latvia', 'Lithuania', 'Macedonia', 'Moldova', 'Montenegro', 'Poland','Romania', 'Russia', 'Serbia', 'Slovakia', 'Slovenia', 'Tajikistan', 'Turkmenistan', 'Ukraine', 'Uzbekistan']), 'Region'] = 'Central and Eastern Europe'

# %%
year18.loc[year18['Country'].isin(['China', 'Hong Kong', 'Japan', 'Mongolia', 'South Korea', 'Taiwan']), 'Region'] = 'Eastern Asia'

# %%
year18.loc[year18['Country'].isin(['Argentina', 'Bolivia', 'Brazil', 'Belize', 'Venezuela', 'Chile', 'Colombia', 'Costa Rica', 'Dominican Republic','Ecuador', 'El Salvador', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 'Peru', 'Suriname', 'Trinidad and Tobago', 'Uruguay', 'Uruguay']), 'Region'] = 'Latin America and Caribbean'

# %%
year18.loc[year18['Country'].isin(['Algeria', 'Bahrain','Egypt','Iran', 'Iraq', 'Israel', 'Jordan', 'Kuwait', 'Lebanon', 'Libya', 'Morocco', 'Oman', 'Palestinian Territories', 'Qatar', 'Saudi Arabia', 'Syria', 'Tunisia', 'Turkey', 'United Arab Emirates', 'Yemen']), 'Region'] = 'Middle East and Northern Africa'

# %%
year18.loc[year18['Country'].isin(['Canada', 'United States']), 'Region'] = 'North America'
year18.loc[year18['Country'].isin(['Cambodia', 'Indonesia', 'Laos', 'Malaysia', 'Myanmar', 'Philippines', 'Singapore','Thailand', 'Vietnam']), 'Region'] = 'Southeastern Asia'
year18.loc[year18['Country'].isin(['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Nepal', 'Pakistan', 'Sri Lanka']), 'Region'] = 'Southern Asia'
year18.loc[year18['Country'].isin(['Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Congo (Brazzaville)', 'Congo (Kinshasa)', 'Djibouti', 'Ethiopia', 'Gabon', 'Ghana', 'Guinea', 'Ivory Coast', 'Kenya', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Mozambique', 'Niger', 'Nigeria', 'Rwanda', 'Senegal', 'Sierra Leone', 'Somaliland region', 'South Africa', 'Sudan', 'Swaziland', 'Tanzania', 'Togo', 'Uganda', 'Zambia', 'Zimbabwe', 'Somalia', 'Namibia']), 'Region'] = 'Sub-Saharan Africa'

# %%
year18.loc[year18['Country'].isin(['North Cyprus','Austria', 'Belgium', 'Cyprus', 'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Iceland', 'Ireland', 'Italy', 'Luxembourg', 'Malta', 'Netherlands', 'North Cyprus', 'Norway', 'Portugal', 'Spain', 'Sweden', 'Switzerland', 'United Kingdom']), 'Region'] = 'Western Europe'

# %%
year18.head(5)
# Out:
#    Rank      Country  Happiness Score  Economy (GDP per Capita)  \
# 0     1      Finland            7.632                     1.305
# 1     2       Norway            7.594                     1.456
# 2     3      Denmark            7.555                     1.351
# 3     4      Iceland            7.495                     1.343
# 4     5  Switzerland            7.487                     1.420
#
#    Family (Social Support)  Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                    1.592                     0.874                   0.681
# 1                    1.582                     0.861                   0.686
# 2                    1.590                     0.868                   0.683
# 3                    1.644                     0.914                   0.677
# 4                    1.549                     0.927                   0.660
#
#    Generosity (Donations to Charity)  Trust (Government Corruption)  Year  \
# ...

# %%
year18 = year18[['Rank', 'Year', 'Country', 'Region', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Generosity (Donations to Charity)']]

# %%
year18.head(5)
# Out:
#    Rank  Year      Country          Region  Happiness Score  \
# 0     1  2018      Finland  Western Europe            7.632
# 1     2  2018       Norway  Western Europe            7.594
# 2     3  2018      Denmark  Western Europe            7.555
# 3     4  2018      Iceland  Western Europe            7.495
# 4     5  2018  Switzerland  Western Europe            7.487
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.305                    1.592
# 1                     1.456                    1.582
# 2                     1.351                    1.590
# 3                     1.343                    1.644
# 4                     1.420                    1.549
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                     0.874                   0.681
# 1                     0.861                   0.686
# 2                     0.868                   0.683
# 3                     0.914                   0.677
# ...

# %%
# checking the null data
year18.isnull().sum()
# Out:
# Rank                                 0
# Year                                 0
# Country                              0
# Region                               1
# Happiness Score                      0
# Economy (GDP per Capita)             0
# Family (Social Support)              0
# Health (Life Expectancy)             0
# Freedom (Life Choices)               0
# Trust (Government Corruption)        1
# Generosity (Donations to Charity)    0
# dtype: int64

# %%
print("Missing Data:\n", year18[year18.isnull().any(axis=1)])
# Out:
# Missing Data:
#      Rank  Year               Country                           Region  \
# 19    20  2018  United Arab Emirates  Middle East and Northern Africa
# 57    58  2018       Northern Cyprus                              NaN
#
#     Happiness Score  Economy (GDP per Capita)  Family (Social Support)  \
# 19            6.774                     2.096                    0.776
# 57            5.835                     1.229                    1.211
#
#     Health (Life Expectancy)  Freedom (Life Choices)  \
# 19                     0.670                   0.284
# 57                     0.909                   0.495
#
#     Trust (Government Corruption)  Generosity (Donations to Charity)
# 19                            NaN                              0.186
# 57                          0.154                              0.179

# %%
# Fill specific missing string data
year18['Country'].fillna('Burundi', inplace=True)

# %%
print("Missing Data:\n", year18[year18.isnull().any(axis=1)])
# Out:
# Missing Data:
#      Rank  Year               Country                           Region  \
# 19    20  2018  United Arab Emirates  Middle East and Northern Africa
# 57    58  2018       Northern Cyprus                              NaN
#
#     Happiness Score  Economy (GDP per Capita)  Family (Social Support)  \
# 19            6.774                     2.096                    0.776
# 57            5.835                     1.229                    1.211
#
#     Health (Life Expectancy)  Freedom (Life Choices)  \
# 19                     0.670                   0.284
# 57                     0.909                   0.495
#
#     Trust (Government Corruption)  Generosity (Donations to Charity)
# 19                            NaN                              0.186
# 57                          0.154                              0.179

# %%
year18['Country'] = year18['Country'].replace('Northern Cyprus', 'North Cyprus')

# %%
year18.loc[year18['Country'].isin(['North Cyprus']), 'Region'] = 'Western Europe'

# %%
print("Missing Data:\n", year18[year18.isnull().any(axis=1)])
# Out:
# Missing Data:
#      Rank  Year               Country                           Region  \
# 19    20  2018  United Arab Emirates  Middle East and Northern Africa
#
#     Happiness Score  Economy (GDP per Capita)  Family (Social Support)  \
# 19            6.774                     2.096                    0.776
#
#     Health (Life Expectancy)  Freedom (Life Choices)  \
# 19                      0.67                   0.284
#
#     Trust (Government Corruption)  Generosity (Donations to Charity)
# 19                            NaN                              0.186

# %%
# check for duplicates
year18[year18.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Generosity (Donations to Charity)]
# Index: []

# %%
# drop the other missing values
year18_clean = year18.dropna()

# %%
year18_clean.shape
# Out:
# (155, 11)

# %%
year18_clean.describe()
# Out:
#              Rank    Year  Happiness Score  Economy (GDP per Capita)  \
# count  155.000000   155.0       155.000000                155.000000
# mean    78.877419  2018.0         5.366897                  0.883677
# std     45.076463     0.0         1.117433                  0.380942
# min      1.000000  2018.0         2.905000                  0.000000
# 25%     40.500000  2018.0         4.451500                  0.612500
# 50%     79.000000  2018.0         5.358000                  0.940000
# 75%    117.500000  2018.0         6.154000                  1.192500
# max    156.000000  2018.0         7.632000                  1.649000
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               155.000000                155.000000
# mean                  1.216058                  0.596877
# std                   0.301286                  0.248312
# min                   0.000000                  0.000000
# ...

# %%
year18_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Rank                               155 non-null    int64
#  1   Year                               155 non-null    int64
#  2   Country                            155 non-null    object
#  3   Region                             155 non-null    object
#  4   Happiness Score                    155 non-null    float64
#  5   Economy (GDP per Capita)           155 non-null    float64
#  6   Family (Social Support)            155 non-null    float64
#  7   Health (Life Expectancy)           155 non-null    float64
#  8   Freedom (Life Choices)             155 non-null    float64
#  9   Trust (Government Corruption)      155 non-null    float64
#  10  Generosity (Donations to Charity)  155 non-null    float64
# ...

# %%
# Export df_ords
year18_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'year18_clean.csv'))

# %% [markdown]
# ### 7. Data Cleaning & Wrangling for 2019

# %%
# check the shape of the Dataframe
year19.shape
# Out:
# (156, 9)

# %%
# check the info of dataframe
year19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
# add new column
year19 ['Year'] = 2019

# %%
# rename columns
year19.rename(columns = {'Overall rank':'Rank', 'Country or region':'Country', 'Score':'Happiness Score', 'GDP per capita':'Economy (GDP per Capita)', 'Social support':'Family (Social Support)', 'Healthy life expectancy': 'Health (Life Expectancy)', 'Freedom to make life choices': 'Freedom (Life Choices)', 'Generosity':'Generosity (Donations to Charity)', 'Perceptions of corruption':'Trust (Government Corruption)'}, inplace = True)

# %%
# Correcting country name 
year19['Country'] = year19['Country'].replace('Northern Cyprus', 'North Cyprus')
year19['Country'] = year19['Country'].replace('North Macedonia', 'Macedonia')

# %%
# Correcting country name 
year19['Country'] = year19['Country'].replace('South Sudan', 'Sudan')
year19['Country'] = year19['Country'].replace('Trinidad & Tobago', 'Trinidad and Tobago')

# %%
#derive Region according to country names using loc()
year19.loc[year19['Country'].isin(['Australia', 'New Zealand']), 'Region'] = 'Australia and New Zealand'
year19.loc[year19['Country'].isin(['Albania', 'Armenia', 'Azerbaijan', 'Belarus', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czech Republic', 'Estonia', 'Georgia', 'Hungary', 'Kazakhstan', 'Kosovo', 'Kyrgyzstan', 'Latvia', 'Lithuania', 'Macedonia', 'Moldova', 'Montenegro', 'Poland','Romania', 'Russia', 'Serbia', 'Slovakia', 'Slovenia', 'Tajikistan', 'Turkmenistan', 'Ukraine', 'Uzbekistan']), 'Region'] = 'Central and Eastern Europe'
year19.loc[year19['Country'].isin(['China', 'Hong Kong', 'Japan', 'Mongolia', 'South Korea', 'Taiwan']), 'Region'] = 'Eastern Asia'
year19.loc[year19['Country'].isin(['Argentina', 'Bolivia', 'Brazil', 'Belize', 'Venezuela', 'Chile', 'Colombia', 'Costa Rica', 'Dominican Republic','Ecuador', 'El Salvador', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 'Peru', 'Suriname', 'Trinidad and Tobago', 'Uruguay', 'Uruguay']), 'Region'] = 'Latin America and Caribbean'
year19.loc[year19['Country'].isin(['Algeria', 'Bahrain','Egypt','Iran', 'Iraq', 'Israel', 'Jordan', 'Kuwait', 'Lebanon', 'Libya', 'Morocco', 'Oman', 'Palestinian Territories', 'Qatar', 'Saudi Arabia', 'Syria', 'Tunisia', 'Turkey', 'United Arab Emirates', 'Yemen']), 'Region'] = 'Middle East and Northern Africa'
year19.loc[year19['Country'].isin(['Canada', 'United States']), 'Region'] = 'North America'
year19.loc[year19['Country'].isin(['Cambodia', 'Indonesia', 'Laos', 'Malaysia', 'Myanmar', 'Philippines', 'Singapore','Thailand', 'Vietnam']), 'Region'] = 'Southeastern Asia'
year19.loc[year19['Country'].isin(['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Nepal', 'Pakistan', 'Sri Lanka']), 'Region'] = 'Southern Asia'
year19.loc[year19['Country'].isin(['Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Congo (Brazzaville)', 'Congo (Kinshasa)', 'Djibouti', 'Ethiopia', 'Gabon', 'Ghana', 'Guinea', 'Ivory Coast', 'Kenya', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Mozambique', 'Niger', 'Nigeria', 'Rwanda', 'Senegal', 'Sierra Leone', 'Gambia','Somaliland region', 'South Africa', 'Sudan', 'Swaziland', 'Tanzania', 'Togo', 'Uganda', 'Zambia', 'Zimbabwe', 'Somalia', 'Namibia']), 'Region'] = 'Sub-Saharan Africa'
year19.loc[year19['Country'].isin(['Austria', 'Belgium', 'Cyprus', 'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Iceland', 'Ireland', 'Italy', 'Luxembourg', 'Malta', 'Netherlands', 'North Cyprus', 'Norway', 'Portugal', 'Spain', 'Sweden', 'Switzerland', 'United Kingdom']), 'Region'] = 'Western Europe'

# %%
#change the order of columns
year19 = year19[['Rank', 'Year', 'Country', 'Region', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Generosity (Donations to Charity)']]

# %%
# check for duplicates
year19[year19.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Generosity (Donations to Charity)]
# Index: []

# %%
year19.head(5)
# Out:
#    Rank  Year      Country          Region  Happiness Score  \
# 0     1  2019      Finland  Western Europe            7.769
# 1     2  2019      Denmark  Western Europe            7.600
# 2     3  2019       Norway  Western Europe            7.554
# 3     4  2019      Iceland  Western Europe            7.494
# 4     5  2019  Netherlands  Western Europe            7.488
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.340                    1.587
# 1                     1.383                    1.573
# 2                     1.488                    1.582
# 3                     1.380                    1.624
# 4                     1.396                    1.522
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                     0.986                   0.596
# 1                     0.996                   0.592
# 2                     1.028                   0.603
# 3                     1.026                   0.591
# ...

# %%
# checking the null data
year19.isnull().sum()
# Out:
# Rank                                 0
# Year                                 0
# Country                              0
# Region                               0
# Happiness Score                      0
# Economy (GDP per Capita)             0
# Family (Social Support)              0
# Health (Life Expectancy)             0
# Freedom (Life Choices)               0
# Trust (Government Corruption)        0
# Generosity (Donations to Charity)    0
# dtype: int64

# %%
# check for duplicates
year19[year19.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Generosity (Donations to Charity)]
# Index: []

# %%
# drop the other missing values
year19_clean = year19.dropna()

# %%
year19_clean.shape
# Out:
# (156, 11)

# %%
year19_clean.describe()
# Out:
#              Rank    Year  Happiness Score  Economy (GDP per Capita)  \
# count  156.000000   156.0       156.000000                156.000000
# mean    78.500000  2019.0         5.407096                  0.905147
# std     45.177428     0.0         1.113120                  0.398389
# min      1.000000  2019.0         2.853000                  0.000000
# 25%     39.750000  2019.0         4.544500                  0.602750
# 50%     78.500000  2019.0         5.379500                  0.960000
# 75%    117.250000  2019.0         6.184500                  1.232500
# max    156.000000  2019.0         7.769000                  1.684000
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               156.000000                156.000000
# mean                  1.208814                  0.725244
# std                   0.299191                  0.242124
# min                   0.000000                  0.000000
# ...

# %%
year19_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Rank                               156 non-null    int64
#  1   Year                               156 non-null    int64
#  2   Country                            156 non-null    object
#  3   Region                             156 non-null    object
#  4   Happiness Score                    156 non-null    float64
#  5   Economy (GDP per Capita)           156 non-null    float64
#  6   Family (Social Support)            156 non-null    float64
#  7   Health (Life Expectancy)           156 non-null    float64
#  8   Freedom (Life Choices)             156 non-null    float64
#  9   Trust (Government Corruption)      156 non-null    float64
#  10  Generosity (Donations to Charity)  156 non-null    float64
# ...

# %%
# Export df_ords
year19_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'year19_clean.csv'))

# %% [markdown]
# ### 8. Data Cleaning & Wrangling for 2020

# %%
# check the shape of the Dataframe
year20.shape
# Out:
# (153, 20)

# %%
# check the info of dataframe
year20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                153 non-null    object
#  1   Regional indicator                          153 non-null    object
#  2   Ladder score                                153 non-null    float64
#  3   Standard error of ladder score              153 non-null    float64
#  4   upperwhisker                                153 non-null    float64
#  5   lowerwhisker                                153 non-null    float64
#  6   Logged GDP per capita                       153 non-null    float64
#  7   Social support                              153 non-null    float64
#  8   Healthy life expectancy                     153 non-null    float64
# ...

# %%
# add new column
year20 ['Year'] = 2020

# %%
year20.head(5)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
#remove unnecessary columns
year20.drop(['Standard error of ladder score', 'upperwhisker','lowerwhisker', 'Logged GDP per capita', 'Social support','Healthy life expectancy','Freedom to make life choices', 'Generosity', 'Perceptions of corruption','Ladder score in Dystopia'], axis=1, inplace=True)

# %%
year20.head(5)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                          1.285190                      1.499526
# 1                          1.326949                      1.503449
# 2                          1.390774                      1.472403
# 3                          1.326502                      1.547567
# 4                          1.424207                      1.495173
#
#    Explained by: Healthy life expectancy  \
# 0                               0.961271
# 1                               0.979333
# 2                               1.040533
# 3                               1.000843
# 4                               1.008072
#
# ...

# %%
# rename columns
year20.rename(columns = {'Country name':'Country', 'Regional indicator':'Region', 'Ladder score':'Happiness Score', 'Explained by: Log GDP per capita':'Economy (GDP per Capita)', 'Explained by: Social support':'Family (Social Support)', 'Explained by: Healthy life expectancy': 'Health (Life Expectancy)', 'Explained by: Freedom to make life choices': 'Freedom (Life Choices)', 'Explained by: Generosity':'Generosity (Donations to Charity)', 'Explained by: Perceptions of corruption':'Trust (Government Corruption)'}, inplace = True)

# %%
# Add the "Rank" column
year20['Rank'] = range(1, len(year20) + 1)

# %%
year20.head(5)
# Out:
#        Country          Region  Happiness Score  Economy (GDP per Capita)  \
# 0      Finland  Western Europe           7.8087                  1.285190
# 1      Denmark  Western Europe           7.6456                  1.326949
# 2  Switzerland  Western Europe           7.5599                  1.390774
# 3      Iceland  Western Europe           7.5045                  1.326502
# 4       Norway  Western Europe           7.4880                  1.424207
#
#    Family (Social Support)  Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                 1.499526                  0.961271                0.662317
# 1                 1.503449                  0.979333                0.665040
# 2                 1.472403                  1.040533                0.628954
# 3                 1.547567                  1.000843                0.661981
# 4                 1.495173                  1.008072                0.670201
#
# ...

# %%
#remove unnecessary columns
year20.drop(['Dystopia + residual'], axis=1, inplace=True)

# %%
#change the order of columns
year20 = year20[['Rank', 'Year', 'Country', 'Region', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Generosity (Donations to Charity)']]

# %%
year20.head(5)
# Out:
#    Rank  Year      Country          Region  Happiness Score  \
# 0     1  2020      Finland  Western Europe           7.8087
# 1     2  2020      Denmark  Western Europe           7.6456
# 2     3  2020  Switzerland  Western Europe           7.5599
# 3     4  2020      Iceland  Western Europe           7.5045
# 4     5  2020       Norway  Western Europe           7.4880
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                  1.285190                 1.499526
# 1                  1.326949                 1.503449
# 2                  1.390774                 1.472403
# 3                  1.326502                 1.547567
# 4                  1.424207                 1.495173
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                  0.961271                0.662317
# 1                  0.979333                0.665040
# 2                  1.040533                0.628954
# 3                  1.000843                0.661981
# ...

# %%
# checking the null data
year20.isnull().sum()
# Out:
# Rank                                 0
# Year                                 0
# Country                              0
# Region                               0
# Happiness Score                      0
# Economy (GDP per Capita)             0
# Family (Social Support)              0
# Health (Life Expectancy)             0
# Freedom (Life Choices)               0
# Trust (Government Corruption)        0
# Generosity (Donations to Charity)    0
# dtype: int64

# %%
# check for duplicates
year20[year20.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Generosity (Donations to Charity)]
# Index: []

# %%
# drop the other missing values
year20_clean = year20.dropna()

# %%
year20_clean.shape
# Out:
# (153, 11)

# %%
year20_clean.describe()
# Out:
#              Rank    Year  Happiness Score  Economy (GDP per Capita)  \
# count  153.000000   153.0        153.00000                153.000000
# mean    77.000000  2020.0          5.47324                  0.868771
# std     44.311398     0.0          1.11227                  0.372416
# min      1.000000  2020.0          2.56690                  0.000000
# 25%     39.000000  2020.0          4.72410                  0.575862
# 50%     77.000000  2020.0          5.51500                  0.918549
# 75%    115.000000  2020.0          6.22850                  1.169229
# max    153.000000  2020.0          7.80870                  1.536676
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               153.000000                153.000000
# mean                  1.155607                  0.692869
# std                   0.286866                  0.254094
# min                   0.000000                  0.000000
# ...

# %%
year20_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Rank                               153 non-null    int64
#  1   Year                               153 non-null    int64
#  2   Country                            153 non-null    object
#  3   Region                             153 non-null    object
#  4   Happiness Score                    153 non-null    float64
#  5   Economy (GDP per Capita)           153 non-null    float64
#  6   Family (Social Support)            153 non-null    float64
#  7   Health (Life Expectancy)           153 non-null    float64
#  8   Freedom (Life Choices)             153 non-null    float64
#  9   Trust (Government Corruption)      153 non-null    float64
#  10  Generosity (Donations to Charity)  153 non-null    float64
# ...

# %%
# Export df_ords
year20_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'year20_clean.csv'))

# %% [markdown]
# ### 9. Data Cleaning & Wrangling for 2021

# %%
# check the shape of the Dataframe
year21.shape
# Out:
# (149, 20)

# %%
# check the info of dataframe
year21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %%
# add new column
year21 ['Year'] = 2021

# %%
year21.head(5)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
#remove unnecessary columns
year21.drop(['Standard error of ladder score', 'upperwhisker','lowerwhisker', 'Logged GDP per capita', 'Social support','Healthy life expectancy','Freedom to make life choices', 'Generosity', 'Perceptions of corruption','Ladder score in Dystopia'], axis=1, inplace=True)

# %%
year21.head(5)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                             1.446                         1.106
# 1                             1.502                         1.108
# 2                             1.566                         1.079
# 3                             1.482                         1.172
# 4                             1.501                         1.079
#
#    Explained by: Healthy life expectancy  \
# 0                                  0.741
# 1                                  0.763
# 2                                  0.816
# 3                                  0.772
# 4                                  0.753
#
# ...

# %%
# rename columns
year21.rename(columns = {'Country name':'Country', 'Regional indicator':'Region', 'Ladder score':'Happiness Score', 'Explained by: Log GDP per capita':'Economy (GDP per Capita)', 'Explained by: Social support':'Family (Social Support)', 'Explained by: Healthy life expectancy': 'Health (Life Expectancy)', 'Explained by: Freedom to make life choices': 'Freedom (Life Choices)', 'Explained by: Generosity':'Generosity (Donations to Charity)', 'Explained by: Perceptions of corruption':'Trust (Government Corruption)'}, inplace = True)

# %%
# Add the "Rank" column
year21['Rank'] = range(1, len(year21) + 1)

# %%
#remove unnecessary columns
year21.drop(['Dystopia + residual'], axis=1, inplace=True)

# %%
#change the order of columns
year21 = year21[['Rank', 'Year', 'Country', 'Region', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Generosity (Donations to Charity)']]

# %%
year21.head(5)
# Out:
#    Rank  Year      Country          Region  Happiness Score  \
# 0     1  2021      Finland  Western Europe            7.842
# 1     2  2021      Denmark  Western Europe            7.620
# 2     3  2021  Switzerland  Western Europe            7.571
# 3     4  2021      Iceland  Western Europe            7.554
# 4     5  2021  Netherlands  Western Europe            7.464
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.446                    1.106
# 1                     1.502                    1.108
# 2                     1.566                    1.079
# 3                     1.482                    1.172
# 4                     1.501                    1.079
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                     0.741                   0.691
# 1                     0.763                   0.686
# 2                     0.816                   0.653
# 3                     0.772                   0.698
# ...

# %%
# checking the null data
year21.isnull().sum()
# Out:
# Rank                                 0
# Year                                 0
# Country                              0
# Region                               0
# Happiness Score                      0
# Economy (GDP per Capita)             0
# Family (Social Support)              0
# Health (Life Expectancy)             0
# Freedom (Life Choices)               0
# Trust (Government Corruption)        0
# Generosity (Donations to Charity)    0
# dtype: int64

# %%
# check for duplicates
year21[year21.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Generosity (Donations to Charity)]
# Index: []

# %%
# drop the other missing values
year21_clean = year21.dropna()

# %%
year21_clean.shape
# Out:
# (149, 11)

# %%
year21_clean.describe()
# Out:
#              Rank    Year  Happiness Score  Economy (GDP per Capita)  \
# count  149.000000   149.0       149.000000                149.000000
# mean    75.000000  2021.0         5.532839                  0.977161
# std     43.156691     0.0         1.073924                  0.404740
# min      1.000000  2021.0         2.523000                  0.000000
# 25%     38.000000  2021.0         4.852000                  0.666000
# 50%     75.000000  2021.0         5.534000                  1.025000
# 75%    112.000000  2021.0         6.255000                  1.323000
# max    149.000000  2021.0         7.842000                  1.751000
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               149.000000                149.000000
# mean                  0.793315                  0.520161
# std                   0.258871                  0.213019
# min                   0.000000                  0.000000
# ...

# %%
year21_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Rank                               149 non-null    int64
#  1   Year                               149 non-null    int64
#  2   Country                            149 non-null    object
#  3   Region                             149 non-null    object
#  4   Happiness Score                    149 non-null    float64
#  5   Economy (GDP per Capita)           149 non-null    float64
#  6   Family (Social Support)            149 non-null    float64
#  7   Health (Life Expectancy)           149 non-null    float64
#  8   Freedom (Life Choices)             149 non-null    float64
#  9   Trust (Government Corruption)      149 non-null    float64
#  10  Generosity (Donations to Charity)  149 non-null    float64
# ...

# %%
# Export df_ords
year21_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'year21_clean.csv'))

# %% [markdown]
# ### 10. Data Cleaning & Wrangling for 2022

# %%
# check the shape of the Dataframe
year22.shape
# Out:
# (147, 12)

# %%
# check the info of dataframe
year22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 12 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   RANK                                        147 non-null    int64
#  1   Country                                     147 non-null    object
#  2   Happiness score                             146 non-null    object
#  3   Whisker-high                                146 non-null    object
#  4   Whisker-low                                 146 non-null    object
#  5   Dystopia (1.83) + residual                  146 non-null    object
#  6   Explained by: GDP per capita                146 non-null    object
#  7   Explained by: Social support                146 non-null    object
#  8   Explained by: Healthy life expectancy       146 non-null    object
#  9   Explained by: Freedom to make life choices  146 non-null    object
# ...

# %%
# add new column
year22 ['Year'] = 2022

# %%
year22.head(5)
# Out:
#    RANK      Country Happiness score Whisker-high Whisker-low  \
# 0     1      Finland           7,821        7,886       7,756
# 1     2      Denmark           7,636        7,710       7,563
# 2     3      Iceland           7,557        7,651       7,464
# 3     4  Switzerland           7,512        7,586       7,437
# 4     5  Netherlands           7,415        7,471       7,359
#
#   Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                      2,518                        1,892
# 1                      2,226                        1,953
# 2                      2,320                        1,936
# 3                      2,153                        2,026
# 4                      2,137                        1,945
#
#   Explained by: Social support Explained by: Healthy life expectancy  \
# 0                        1,258                                 0,775
# 1                        1,243                                 0,777
# ...

# %%
#remove unnecessary columns
year22.drop(['Whisker-high','Whisker-low', 'Dystopia (1.83) + residual'], axis=1, inplace=True)

# %%
year22.head(5)
# Out:
#    RANK      Country Happiness score Explained by: GDP per capita  \
# 0     1      Finland           7,821                        1,892
# 1     2      Denmark           7,636                        1,953
# 2     3      Iceland           7,557                        1,936
# 3     4  Switzerland           7,512                        2,026
# 4     5  Netherlands           7,415                        1,945
#
#   Explained by: Social support Explained by: Healthy life expectancy  \
# 0                        1,258                                 0,775
# 1                        1,243                                 0,777
# 2                        1,320                                 0,803
# 3                        1,226                                 0,822
# 4                        1,206                                 0,787
#
#   Explained by: Freedom to make life choices Explained by: Generosity  \
# 0                                      0,736                    0,109
# ...

# %%
# rename columns
year22.rename(columns = {'RANK':'Rank', 'Happiness score':'Happiness Score', 'Explained by: GDP per capita':'Economy (GDP per Capita)', 'Explained by: Social support':'Family (Social Support)', 'Explained by: Healthy life expectancy': 'Health (Life Expectancy)', 'Explained by: Freedom to make life choices': 'Freedom (Life Choices)', 'Explained by: Generosity':'Generosity (Donations to Charity)', 'Explained by: Perceptions of corruption':'Trust (Government Corruption)'}, inplace = True)

# %%
year22.head(5)
# Out:
#    Rank      Country Happiness Score Economy (GDP per Capita)  \
# 0     1      Finland           7,821                    1,892
# 1     2      Denmark           7,636                    1,953
# 2     3      Iceland           7,557                    1,936
# 3     4  Switzerland           7,512                    2,026
# 4     5  Netherlands           7,415                    1,945
#
#   Family (Social Support) Health (Life Expectancy) Freedom (Life Choices)  \
# 0                   1,258                    0,775                  0,736
# 1                   1,243                    0,777                  0,719
# 2                   1,320                    0,803                  0,718
# 3                   1,226                    0,822                  0,677
# 4                   1,206                    0,787                  0,651
#
#   Generosity (Donations to Charity) Trust (Government Corruption)  Year
# 0                             0,109                         0,534  2022
# ...

# %%
# Correcting country name 
year22['Country'] = year22['Country'].replace('Northern Cyprus', 'North Cyprus')
year22['Country'] = year22['Country'].replace('North Macedonia', 'Macedonia')
year22['Country'] = year22['Country'].replace('South Sudan', 'Sudan')
year22['Country'] = year22['Country'].replace('Trinidad & Tobago', 'Trinidad and Tobago')

# %%
# Correcting country name 
year22['Country'] = year22['Country'].replace('Luxembourg*', 'Luxembourg')
year22['Country'] = year22['Country'].replace('Czechia', 'Czech Republic')
year22['Country'] = year22['Country'].replace('Taiwan Province of China', 'Taiwan')
year22['Country'] = year22['Country'].replace('Guatemala*', 'Guatemala')
year22['Country'] = year22['Country'].replace('Kuwait*', 'Kuwait')
year22['Country'] = year22['Country'].replace('Belarus*', 'Belarus')
year22['Country'] = year22['Country'].replace('North Cyprus*', 'North Cyprus')
year22['Country'] = year22['Country'].replace('Hong Kong S.A.R. of China', 'Hong Kong')
year22['Country'] = year22['Country'].replace('Libya*', 'Libya')
year22['Country'] = year22['Country'].replace('Turkmenistan*', 'Turkmenistan')
year22['Country'] = year22['Country'].replace('Congo', 'Congo (Brazzaville)')
year22['Country'] = year22['Country'].replace('Niger*', 'Niger')
year22['Country'] = year22['Country'].replace('Comoros*', 'Comoros')
year22['Country'] = year22['Country'].replace('Palestinian Territories*', 'Palestinian Territories')
year22['Country'] = year22['Country'].replace('Eswatini, Kingdom of*', 'Eswatini, Kingdom of')
year22['Country'] = year22['Country'].replace('Madagascar*', 'Madagascar')
year22['Country'] = year22['Country'].replace('Chad*', 'Chad')
year22['Country'] = year22['Country'].replace('Yemen*', 'Yemen')
year22['Country'] = year22['Country'].replace('Mauritania*', 'Mauritania')
year22['Country'] = year22['Country'].replace('Lesotho*', 'Lesotho')
year22['Country'] = year22['Country'].replace('Botswana*', 'Botswana')
year22['Country'] = year22['Country'].replace('Rwanda*', 'Rwanda')
year22['Country'] = year22['Country'].replace('Azerbaijan*', 'Azerbaijan')
year22['Country'] = year22['Country'].replace('Gambia*', 'Gambia')
year22['Country'] = year22['Country'].replace('Liberia*', 'Liberia')

# %%
# derive Region according to country names using loc()
year22.loc[year22['Country'].isin(['Australia', 'New Zealand']), 'Region'] = 'Australia and New Zealand'
year22.loc[year22['Country'].isin(['Albania', 'Armenia', 'Azerbaijan', 'Belarus', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czech Republic', 'Estonia', 'Georgia', 'Hungary', 'Kazakhstan', 'Kosovo', 'Kyrgyzstan', 'Latvia', 'Lithuania', 'Macedonia', 'Moldova', 'Montenegro', 'Poland','Romania', 'Russia', 'Serbia', 'Slovakia', 'Slovenia', 'Tajikistan', 'Turkmenistan', 'Ukraine', 'Uzbekistan']), 'Region'] = 'Central and Eastern Europe'
year22.loc[year22['Country'].isin(['China', 'Hong Kong', 'Japan', 'Mongolia', 'South Korea', 'Taiwan']), 'Region'] = 'Eastern Asia'
year22.loc[year22['Country'].isin(['Argentina', 'Bolivia', 'Brazil', 'Belize', 'Venezuela', 'Chile', 'Colombia', 'Costa Rica', 'Dominican Republic','Ecuador', 'El Salvador', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 'Peru', 'Suriname', 'Trinidad and Tobago', 'Uruguay', 'Uruguay']), 'Region'] = 'Latin America and Caribbean'
year22.loc[year22['Country'].isin(['Algeria', 'Bahrain','Egypt','Iran', 'Iraq', 'Israel', 'Jordan', 'Kuwait', 'Lebanon', 'Libya', 'Morocco', 'Oman', 'Palestinian Territories', 'Qatar', 'Saudi Arabia', 'Syria', 'Tunisia', 'Turkey', 'United Arab Emirates', 'Yemen']), 'Region'] = 'Middle East and Northern Africa'
year22.loc[year22['Country'].isin(['Canada', 'United States']), 'Region'] = 'North America'
year22.loc[year22['Country'].isin(['Cambodia', 'Indonesia', 'Laos', 'Malaysia', 'Myanmar', 'Philippines', 'Singapore','Thailand', 'Vietnam']), 'Region'] = 'Southeastern Asia'
year22.loc[year22['Country'].isin(['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Nepal', 'Pakistan', 'Sri Lanka']), 'Region'] = 'Southern Asia'
year22.loc[year22['Country'].isin(['Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Congo (Brazzaville)', 'Congo (Kinshasa)', 'Djibouti', 'Ethiopia', 'Gabon', 'Ghana', 'Guinea', 'Ivory Coast', 'Kenya', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Mozambique', 'Niger', 'Nigeria', 'Rwanda', 'Senegal', 'Sierra Leone', 'Gambia','Somaliland region', 'South Africa', 'Sudan', 'Swaziland', 'Tanzania', 'Togo', 'Uganda', 'Zambia', 'Zimbabwe', 'Somalia', 'Namibia']), 'Region'] = 'Sub-Saharan Africa'
year22.loc[year22['Country'].isin(['Austria', 'Belgium', 'Cyprus', 'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Iceland', 'Ireland', 'Italy', 'Luxembourg', 'Malta', 'Netherlands', 'North Cyprus', 'Norway', 'Portugal', 'Spain', 'Sweden', 'Switzerland', 'United Kingdom']), 'Region'] = 'Western Europe'

# %%
#change the order of columns
year22 = year22[['Rank', 'Year', 'Country', 'Region', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Generosity (Donations to Charity)']]

# %%
year22.head(5)
# Out:
#    Rank  Year      Country          Region Happiness Score  \
# 0     1  2022      Finland  Western Europe           7,821
# 1     2  2022      Denmark  Western Europe           7,636
# 2     3  2022      Iceland  Western Europe           7,557
# 3     4  2022  Switzerland  Western Europe           7,512
# 4     5  2022  Netherlands  Western Europe           7,415
#
#   Economy (GDP per Capita) Family (Social Support) Health (Life Expectancy)  \
# 0                    1,892                   1,258                    0,775
# 1                    1,953                   1,243                    0,777
# 2                    1,936                   1,320                    0,803
# 3                    2,026                   1,226                    0,822
# 4                    1,945                   1,206                    0,787
#
#   Freedom (Life Choices) Trust (Government Corruption)  \
# 0                  0,736                         0,534
# ...

# %%
# checking the null data
year22.isnull().sum()
# Out:
# Rank                                 0
# Year                                 0
# Country                              0
# Region                               2
# Happiness Score                      1
# Economy (GDP per Capita)             1
# Family (Social Support)              1
# Health (Life Expectancy)             1
# Freedom (Life Choices)               1
# Trust (Government Corruption)        1
# Generosity (Donations to Charity)    1
# dtype: int64

# %%
print("Missing Data:\n", year22[year22.isnull().any(axis=1)])
# Out:
# Missing Data:
#       Rank  Year               Country Region Happiness Score  \
# 124   125  2022  Eswatini, Kingdom of    NaN           4,396
# 146   147  2022                    xx    NaN             NaN
#
#     Economy (GDP per Capita) Family (Social Support) Health (Life Expectancy)  \
# 124                    1,274                   0,786                    0,197
# 146                      NaN                     NaN                      NaN
#
#     Freedom (Life Choices) Trust (Government Corruption)  \
# 124                  0,259                         0,154
# 146                    NaN                           NaN
#
#     Generosity (Donations to Charity)
# 124                             0,038
# 146                               NaN

# %%
# Remove the missing data
year22 = year22.drop(124, axis=0)

# %%
year22 = year22.drop(146, axis=0)

# %%
print("Missing Data:\n", year22[year22.isnull().any(axis=1)])
# Out:
# Missing Data:
#  Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Generosity (Donations to Charity)]
# Index: []

# %%
# check for duplicates
year22[year22.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Generosity (Donations to Charity)]
# Index: []

# %%
# drop the other missing values
year22_clean = year22.dropna()

# %%
year22_clean.shape
# Out:
# (145, 11)

# %%
year22_clean.describe()
# Out:
#              Rank    Year
# count  145.000000   145.0
# mean    73.144828  2022.0
# std     42.218180     0.0
# min      1.000000  2022.0
# 25%     37.000000  2022.0
# 50%     73.000000  2022.0
# 75%    109.000000  2022.0
# max    146.000000  2022.0

# %%
# Convert the values in the 'col2' column from integers to strings and replace the comma with a decimal point
year22_clean['Happiness Score'] = year22_clean['Happiness Score'].astype(str).str.replace(',', '.').astype(float)
year22_clean['Economy (GDP per Capita)'] = year22_clean['Economy (GDP per Capita)'].astype(str).str.replace(',', '.').astype(float)
year22_clean['Family (Social Support)'] = year22_clean['Family (Social Support)'].astype(str).str.replace(',', '.').astype(float)
year22_clean['Health (Life Expectancy)'] = year22_clean['Health (Life Expectancy)'].astype(str).str.replace(',', '.').astype(float)
year22_clean['Freedom (Life Choices)'] = year22_clean['Freedom (Life Choices)'].astype(str).str.replace(',', '.').astype(float)
year22_clean['Trust (Government Corruption)'] = year22_clean['Trust (Government Corruption)'].astype(str).str.replace(',', '.').astype(float)
year22_clean['Generosity (Donations to Charity)'] = year22_clean['Generosity (Donations to Charity)'].astype(str).str.replace(',', '.').astype(float)

# %%
year22_clean.head()
# Out:
#    Rank  Year      Country          Region  Happiness Score  \
# 0     1  2022      Finland  Western Europe            7.821
# 1     2  2022      Denmark  Western Europe            7.636
# 2     3  2022      Iceland  Western Europe            7.557
# 3     4  2022  Switzerland  Western Europe            7.512
# 4     5  2022  Netherlands  Western Europe            7.415
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.892                    1.258
# 1                     1.953                    1.243
# 2                     1.936                    1.320
# 3                     2.026                    1.226
# 4                     1.945                    1.206
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                     0.775                   0.736
# 1                     0.777                   0.719
# 2                     0.803                   0.718
# 3                     0.822                   0.677
# ...

# %%
year22_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145 entries, 0 to 145
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Rank                               145 non-null    int64
#  1   Year                               145 non-null    int64
#  2   Country                            145 non-null    object
#  3   Region                             145 non-null    object
#  4   Happiness Score                    145 non-null    float64
#  5   Economy (GDP per Capita)           145 non-null    float64
#  6   Family (Social Support)            145 non-null    float64
#  7   Health (Life Expectancy)           145 non-null    float64
#  8   Freedom (Life Choices)             145 non-null    float64
#  9   Trust (Government Corruption)      145 non-null    float64
#  10  Generosity (Donations to Charity)  145 non-null    float64
# ...

# %%
# Export df_ords
year22_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'year22_clean.csv'))

# %% [markdown]
# ### 11. Merging Dataflames

# %%
df_years = (year15_clean, year16_clean, year17_clean, year18_clean, year19_clean, year20_clean, year21_clean, year22_clean)

# %%
df_merged = pd.concat(df_years)

# %%
df_merged.head()
# Out:
#    Rank  Year      Country          Region  Happiness Score  \
# 0     1  2015  Switzerland  Western Europe            7.587
# 1     2  2015      Iceland  Western Europe            7.561
# 2     3  2015      Denmark  Western Europe            7.527
# 3     4  2015       Norway  Western Europe            7.522
# 4     5  2015       Canada   North America            7.427
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                   1.39651                  1.34951
# 1                   1.30232                  1.40223
# 2                   1.32548                  1.36058
# 3                   1.45900                  1.33095
# 4                   1.32629                  1.32261
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                   0.94143                 0.66557
# 1                   0.94784                 0.62877
# 2                   0.87464                 0.64938
# 3                   0.88521                 0.66973
# ...

# %%
#Exporting to ensure merge successful in Excel 
df_merged.to_csv(os.path.join(path, '02 Data', 'Prepared Data', '2Merged_dataset.csv'), index=False)

# %% [markdown]
# ### 12. Data Cleaning

# %%
#Importing clean/merged dataset
df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', '2Merged_dataset.csv'), index_col = False)

# %%
df
# Out:
#       Rank  Year      Country                           Region  \
# 0        1  2015  Switzerland                   Western Europe
# 1        2  2015      Iceland                   Western Europe
# 2        3  2015      Denmark                   Western Europe
# 3        4  2015       Norway                   Western Europe
# 4        5  2015       Canada                    North America
# ...    ...   ...          ...                              ...
# 1223   142  2022     Botswana               Sub-Saharan Africa
# 1224   143  2022       Rwanda               Sub-Saharan Africa
# 1225   144  2022     Zimbabwe               Sub-Saharan Africa
# 1226   145  2022      Lebanon  Middle East and Northern Africa
# 1227   146  2022  Afghanistan                    Southern Asia
#
#       Happiness Score  Economy (GDP per Capita)  Family (Social Support)  \
# 0               7.587                   1.39651                  1.34951
# ...

# %%
#Checking dataframe rows and columns 
df.shape
# Out:
# (1228, 11)

# %%
# Renaming RANK column for 
df.rename(columns = {'Rank' : 'Country Rank'}, inplace = True)

# %%
#Checking for nulls 
df.isnull().sum()
# Out:
# Country Rank                         0
# Year                                 0
# Country                              0
# Region                               0
# Happiness Score                      0
# Economy (GDP per Capita)             0
# Family (Social Support)              0
# Health (Life Expectancy)             0
# Freedom (Life Choices)               0
# Trust (Government Corruption)        0
# Generosity (Donations to Charity)    0
# dtype: int64

# %%
#Checking for duplicates
df_dups = df[df.duplicated()]
df_dups
# Out:
# Empty DataFrame
# Columns: [Country Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Generosity (Donations to Charity)]
# Index: []

# %% [markdown]
# ### 13. Descriptive Statistics

# %%
#Descriptive Statistics 
df.describe()
# Out:
#        Country Rank         Year  Happiness Score  Economy (GDP per Capita)  \
# count   1228.000000  1228.000000      1228.000000               1228.000000
# mean      77.429967  2018.444625         5.429839                  0.975100
# std       44.471587     2.282286         1.115219                  0.434342
# min        1.000000  2015.000000         2.404000                  0.000000
# 25%       39.000000  2016.000000         4.585500                  0.667806
# 50%       77.000000  2018.000000         5.410500                  1.011155
# 75%      116.000000  2020.000000         6.224075                  1.295882
# max      158.000000  2022.000000         7.842000                  2.209000
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count              1228.000000               1228.000000
# mean                  1.033395                  0.608417
# std                   0.329637                  0.241153
# ...

# %%
#Checking for mixed-type columns 
df.dtypes
# Out:
# Country Rank                           int64
# Year                                   int64
# Country                               object
# Region                                object
# Happiness Score                      float64
# Economy (GDP per Capita)             float64
# Family (Social Support)              float64
# Health (Life Expectancy)             float64
# Freedom (Life Choices)               float64
# Trust (Government Corruption)        float64
# Generosity (Donations to Charity)    float64
# dtype: object

# %% [markdown]
# ### 14. Exporting Cleaned Dataframe

# %%
df.to_csv(os.path.join(path, '02 Data', 'Prepared Data', '2Cleaned_dataset.csv'), index=False)
